# %%
import os
import csv
import pandas as pd
import numpy as np

# %%
load_file = "astronaut_format.csv"
load_file1 = "eva_format.csv"

astronaut_format_df = pd.read_csv(load_file)
eva_format_df = pd.read_csv(load_file1)

# %%
eva_format_df["Undergraduate Major"] = ""
eva_format_df["Graduate Major"] = ""
eva_format_df.head(5)
# Out:
#    EVA # Country           Crew      Vehicle               Date Duration  \
# 0    1.0     USA       Ed White    Gemini IV         06/03/1965     0:36
# 1    2.0     USA    David Scott  Gemini VIII  March 16-17, 1966     0:00
# 2    3.0     USA  Eugene Cernan  Gemini IX-A         06/05/1966     2:07
# 3    4.0     USA   Mike Collins     Gemini X         07/19/1966     0:50
# 4    5.0     USA   Mike Collins     Gemini X         07/20/1966     0:39
#
#                                              Purpose Undergraduate Major  \
# 0  First U.S. EVA. Used HHMU and took  photos.  G...
# 1  HHMU EVA cancelled before starting by stuck on...
# 2  Inadequate restraints, stiff 25ft umbilical an...
# 3  Standup EVA.  UV photos of stars.  Ended by ey...
# 4  Retrieved MMOD experiment from docked Agena.  ...
#
#   Graduate Major
# 0
# 1
# 2
# 3
# 4

# %%
astronaut_format_df.head(11)
# Out:
#                    Name    Year  Group    Status  Birth Date  \
# 0       Joseph M. Acaba  2004.0   19.0    Active   5/17/1967
# 1        Loren W. Acton     NaN    NaN   Retired    3/7/1936
# 2      James C. Adamson  1984.0   10.0   Retired    3/3/1946
# 3       Thomas D. Akers  1987.0   12.0   Retired   5/20/1951
# 4           Buzz Aldrin  1963.0    3.0   Retired   1/20/1930
# 5       Andrew M. Allen  1987.0   12.0   Retired    8/4/1955
# 6       Joseph P. Allen  1967.0    6.0   Retired   6/27/1937
# 7       Scott D. Altman  1995.0   15.0   Retired   8/15/1959
# 8     William A. Anders  1963.0    3.0   Retired  10/17/1933
# 9   Clayton C. Anderson  1998.0   17.0   Retired   2/23/1959
# 10  Michael P. Anderson  1995.0   15.0  Deceased  12/25/1959
#
#             Birth Place Gender  \
# 0         Inglewood, CA   Male
# 1          Lewiston, MT   Male
# 2            Warsaw, NY   Male
# 3         St. Louis, MO   Male
# 4         Montclair, NJ   Male
# 5      Philadelphia, PA   Male
# 6   Crawsfordsville, IN   Male
# 7           Lincoln, IL   Male
# 8             Hong Kong   Male
# 9             Omaha, NE   Male
# 10      Plattsburgh, NY   Male
#
#                                            Alma Mater  \
# 0   University of California-Santa Barbara; Univer...
# 1    Montana State University; University of Colorado
# 2           US Military Academy; Princeton University
# 3                        University of Missouri-Rolla
# 4                            US Military Academy; MIT
# 5         Villanova University; University of Florida
# 6                  DePauw University; Yale University
# 7   University of Illinois; US Naval Postgraduate ...
# 8   US Naval Academy; Air Force Institute of Techn...
# 9             Hastings College; Iowa State University
# 10     University of Washington; Creighton University
#
#                          Undergraduate Major            Graduate Major  ...  \
# 0                                    Geology                   Geology  ...
# 1                        Engineering Physics             Solar Physics  ...
# 2                                Engineering     Aerospace Engineering  ...
# 3                        Applied Mathematics       Applied Mathematics  ...
# 4                     Mechanical Engineering              Astronautics  ...
# 5                     Mechanical Engineering   Business Administration  ...
# 6                      Mathematics & Physics                   Physics  ...
# 7   Aeronautical & Astronautical Engineering  Aeronautical Engineering  ...
# 8                        Nuclear Engineering       Nuclear Engineering  ...
# 9                                    Physics     Aerospace Engineering  ...
# 10                       Physics & Astronomy                   Physics  ...
#
#    Space Flights Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0              2              3307            2              13.0
# 1              1               190            0               0.0
# 2              2               334            0               0.0
# 3              4               814            4              29.0
# 4              2               289            2               8.0
# 5              3               906            0               0.0
# 6              2               313            2              12.0
# 7              4              1236            0               0.0
# 8              1               147            0               0.0
# 9              2              4005            6              38.0
# 10             2               594            0               0.0
#
#                                              Missions  Death Date  \
# 0              STS-119 (Discovery), ISS-31/32 (Soyuz)         NaN
# 1                               STS 51-F (Challenger)         NaN
# 2                STS-28 (Columbia), STS-43 (Atlantis)         NaN
# 3   STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...         NaN
# 4                                Gemini 12, Apollo 11         NaN
# 5   STS-46 (Atlantis), STS-62 (Columbia), STS-75 (...         NaN
# 6               ST-5 (Columbia), STS 51-A (Discovery)         NaN
# 7   STS-90 (Columbia), STS-106 (Atlantis), STS-109...         NaN
# 8                                            Apollo 8         NaN
# 9   STS-117/120 (Atlantis/Discovery), STS-131 (Dis...         NaN
# 10              STS-89 (Endeavor), STS-107 (Columbia)    2/1/2003
#
#          Death Mission Last Name First Name         Full Name
# 0                  NaN     Acaba     Joseph      Joseph Acaba
# 1                  NaN     Acton      Loren       Loren Acton
# 2                  NaN   Adamson      James     James Adamson
# 3                  NaN     Akers     Thomas      Thomas Akers
# 4                  NaN    Aldrin       Buzz       Buzz Aldrin
# 5                  NaN     Allen     Andrew      Andrew Allen
# 6                  NaN     Allen     Joseph      Joseph Allen
# 7                  NaN    Altman      Scott      Scott Altman
# 8                  NaN    Anders    William    William Anders
# 9                  NaN  Anderson    Clayton  Clayton Anderson
# 10  STS-107 (Columbia)  Anderson    Michael  Michael Anderson
#
# [11 rows x 22 columns]

# %%
count=0
count2=0
for name_crew in eva_format_df["Crew"]:
    count+=1
    count2=0
    for full_name in astronaut_format_df["Full Name"]:
        count2+=1
        if full_name in name_crew:
            un_degree = astronaut_format_df.iloc[count2-1,8]
            grad_degree = astronaut_format_df.iloc[count2-1,9]
            if eva_format_df.iloc[count-1,7] == "":
                eva_format_df.iloc[count-1,7] = un_degree
            else:
                eva_format_df.iloc[count-1,7] = f"{eva_format_df.iloc[count-1,7]}, {un_degree}"
            
            if eva_format_df.iloc[count-1,8] == "":
                eva_format_df.iloc[count-1,8] = grad_degree
            else:
                eva_format_df.iloc[count-1,8] = f"{eva_format_df.iloc[count-1,8]}, {grad_degree}"

# %%
eva_format_df = eva_format_df.fillna("Not listed")
eva_format_df = eva_format_df.replace("","Not listed")
eva_format_df.head(15)
# Out:
#     EVA # Country                        Crew      Vehicle               Date  \
# 0     1.0     USA                    Ed White    Gemini IV         06/03/1965
# 1     2.0     USA                 David Scott  Gemini VIII  March 16-17, 1966
# 2     3.0     USA               Eugene Cernan  Gemini IX-A         06/05/1966
# 3     4.0     USA                Mike Collins     Gemini X         07/19/1966
# 4     5.0     USA                Mike Collins     Gemini X         07/20/1966
# 5     6.0     USA              Richard Gordon    Gemini XI         09/13/1966
# 6     7.0     USA              Richard Gordon    Gemini XI         09/14/1966
# 7     8.0     USA                 Buzz Aldrin   Gemini XII         11/12/1966
# 8     9.0     USA                 Buzz Aldrin   Gemini XII         11/13/1966
# 9    10.0     USA                 Buzz Aldrin   Gemini XII         11/14/1966
# 10   11.0     USA                 David Scott     Apollo 9         03/06/1969
# 11   12.0     USA            Russ Schweickart     Apollo 9         03/06/1969
# 12   13.0     USA  Neil Armstrong|Buzz Aldrin    Apollo 11         07/20/1969
# 13   14.0     USA  Neil Armstrong|Buzz Aldrin    Apollo 11         07/20/1969
# 14   15.0     USA      Allen Bean|Pete Conrad    Apollo 12         11/19/1969
#
#    Duration                                            Purpose  \
# 0      0:36  First U.S. EVA. Used HHMU and took  photos.  G...
# 1      0:00  HHMU EVA cancelled before starting by stuck on...
# 2      2:07  Inadequate restraints, stiff 25ft umbilical an...
# 3      0:50  Standup EVA.  UV photos of stars.  Ended by ey...
# 4      0:39  Retrieved MMOD experiment from docked Agena.  ...
# 5      0:44  Attached tether between Agena and Gemini.  EVA...
# 6      2:10   Standup EVA.  Took star photos. Agena tether ops
# 7      2:29     Standup EVA.  Science tasks.  Took star photos
# 8      2:06  Attached tether between Agena and Gemini.  UV ...
# 9      0:55   Standup EVA.  Jettisoned equipment.  Took photos
# 10     0:47  Standup EVA from crew module.  Retrieved therm...
# 11     0:51  Lunar module based.  Took photos.  Evaluated f...
# 12     2:32  First to walk on the moon.  Some trouble getti...
# 13     0:05  Jettison suit backpacks and equip to lighten a...
# 14     3:39  Collected 75.6 lb of geologic material.  ALSEP...
#
#                                  Undergraduate Major  \
# 0                                         Not listed
# 1                                         Not listed
# 2                             Electrical Engineering
# 3                                         Not listed
# 4                                         Not listed
# 5                                          Chemistry
# 6                                          Chemistry
# 7                             Mechanical Engineering
# 8                             Mechanical Engineering
# 9                             Mechanical Engineering
# 10                                        Not listed
# 11                                        Not listed
# 12  Mechanical Engineering, Aeronautical Engineering
# 13  Mechanical Engineering, Aeronautical Engineering
# 14                                        Not listed
#
#                          Graduate Major
# 0              Aeronautical Engineering
# 1            Aeronautics & Astronautics
# 2              Aeronautical Engineering
# 3                            Not listed
# 4                            Not listed
# 5                            Not listed
# 6                            Not listed
# 7                          Astronautics
# 8                          Astronautics
# 9                          Astronautics
# 10           Aeronautics & Astronautics
# 11                           Not listed
# 12  Astronautics, Aerospace Engineering
# 13  Astronautics, Aerospace Engineering
# 14                           Not listed

# %%
eva_format_df.to_csv('merged_file.csv', index=False)
